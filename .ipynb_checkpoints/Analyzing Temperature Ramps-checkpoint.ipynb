# %%
import numpy as np
from numpy.fft import fft2, ifft2, fftshift
import matplotlib
from matplotlib import pyplot as plt
from matplotlib import cm
import scipy
from scipy import interpolate

#Import some image analysis functions
from scipy.ndimage import gaussian_filter1d as gf1d
from scipy.ndimage import gaussian_filter as gf
from scipy.ndimage import uniform_filter as uf

import sys

# %matplotlib notebook

# %%
def norm_by_avg_init(data):
    ndata = data / np.mean(data[1:10])
    #ndata = data / data.min()
    return ndata

# %%
main_dir = "Y:\\Dennis Terwilliger\\Data\\"
sub_dir = "2020-11-05\\"
filenm = "2020-11-05 Trios data.csv"

# %%
up_ramp_4Hz_01 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (1,2,3))
up_ramp_4Hz_02 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (17,18,19))

up_ramp_12Hz_01 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (9,10,11))
up_ramp_12Hz_02 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (25,26,27))
up_ramp_12Hz_03 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (41,42,43))

up_ramp_8Hz_01 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (33,34,35))
up_ramp_8Hz_02 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (49,50,51))

up_ramp_05Hz_01 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (54,55,56))

# %%
up_ramp_4Hz_02.shape
# Out:
# (510, 3)

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10
plt.semilogy(up_ramp_05Hz_01[skip_time:,1], up_ramp_05Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.1),label="0.5 Hz, 11/5, 1")

plt.semilogy(up_ramp_4Hz_01[skip_time:,1], up_ramp_4Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.3),label="4 Hz, 11/5, 1")
plt.semilogy(up_ramp_4Hz_02[skip_time:,1], up_ramp_4Hz_02[skip_time:,0],'.',ms=markerSize,c=cmap(0.3),label="4 Hz, 11/5, 2")

plt.semilogy(up_ramp_8Hz_01[skip_time:,1], up_ramp_8Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.5),label="8 Hz, 11/5, 1")
plt.semilogy(up_ramp_8Hz_02[skip_time:,1], up_ramp_8Hz_02[skip_time:,0],'.',ms=markerSize,c=cmap(0.5),label="8 Hz, 11/5, 2")

plt.semilogy(up_ramp_12Hz_01[skip_time:,1], up_ramp_12Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 1")
plt.semilogy(up_ramp_12Hz_02[skip_time:,1], up_ramp_12Hz_02[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 2")
plt.semilogy(up_ramp_12Hz_03[skip_time:,1], up_ramp_12Hz_03[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 3")

plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)


#ax.set_xticks([1.0, 10, 40])
#ax.set_xticklabels(['1.0','10','40'], fontsize=10)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10
plt.semilogy(up_ramp_05Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_05Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.1),label="0.5 Hz, 11/5, 1")

plt.semilogy(up_ramp_4Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.3),label="4 Hz, 11/5, 1")
plt.semilogy(up_ramp_4Hz_02[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_02[skip_time:,0]),'.',ms=markerSize,c=cmap(0.3),label="4 Hz, 11/5, 2")

plt.semilogy(up_ramp_8Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5),label="8 Hz, 11/5, 1")
plt.semilogy(up_ramp_8Hz_02[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_02[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5),label="8 Hz, 11/5, 2")

plt.semilogy(up_ramp_12Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 1")
plt.semilogy(up_ramp_12Hz_02[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_02[skip_time:,0]),'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 2")
plt.semilogy(up_ramp_12Hz_03[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_03[skip_time:,0]),'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 3")

plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
main_dir = "Y:\\Dennis Terwilliger\\Data\\"
sub_dir = "2020-10-30\\"
filenm = "2020-10-30 Trios data.csv"

up_ramp_7Hz_1030 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (1,2,3))
up_ramp_12Hz_1030 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (9,10,11))
up_ramp_14Hz_1030 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (17,18,19))
up_ramp_16Hz_1030 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (25,26,27))
up_ramp_20Hz_1030 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (33,34,35))
up_ramp_30Hz_1030 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (41,42,43))

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10
plt.semilogy(up_ramp_7Hz_1030[skip_time:,1], up_ramp_7Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.1),label="7 Hz, 10/30")
plt.semilogy(up_ramp_12Hz_1030[skip_time:,1], up_ramp_12Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.2),label="12 Hz, 10/30")
plt.semilogy(up_ramp_14Hz_1030[skip_time:,1], up_ramp_14Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.3),label="14 Hz, 10/30")
plt.semilogy(up_ramp_16Hz_1030[skip_time:,1], up_ramp_16Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.4),label="16 Hz, 10/30")
plt.semilogy(up_ramp_20Hz_1030[skip_time:,1], up_ramp_20Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.5),label="20 Hz, 10/30")
plt.semilogy(up_ramp_30Hz_1030[skip_time:,1], up_ramp_30Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.6),label="30 Hz, 10/30")


plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_05Hz_01[skip_time:,1], up_ramp_05Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.1),label="0.5 Hz, 11/5, 1")

plt.semilogy(up_ramp_4Hz_01[skip_time:,1], up_ramp_4Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.3),label="4 Hz, 11/5, 1")
plt.semilogy(up_ramp_4Hz_02[skip_time:,1], up_ramp_4Hz_02[skip_time:,0],'.',ms=markerSize,c=cmap(0.3),label="4 Hz, 11/5, 2")

plt.semilogy(up_ramp_7Hz_1030[skip_time:,1], up_ramp_7Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.4),label="7 Hz, 10/30")

plt.semilogy(up_ramp_8Hz_01[skip_time:,1], up_ramp_8Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.5),label="8 Hz, 11/5, 1")
plt.semilogy(up_ramp_8Hz_02[skip_time:,1], up_ramp_8Hz_02[skip_time:,0],'.',ms=markerSize,c=cmap(0.5),label="8 Hz, 11/5, 2")

plt.semilogy(up_ramp_12Hz_01[skip_time:,1], up_ramp_12Hz_01[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 1")
plt.semilogy(up_ramp_12Hz_02[skip_time:,1], up_ramp_12Hz_02[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 2")
plt.semilogy(up_ramp_12Hz_03[skip_time:,1], up_ramp_12Hz_03[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 3")


plt.semilogy(up_ramp_12Hz_1030[skip_time:,1], up_ramp_12Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 10/30")
plt.semilogy(up_ramp_14Hz_1030[skip_time:,1], up_ramp_14Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.8),label="14 Hz, 10/30")
plt.semilogy(up_ramp_16Hz_1030[skip_time:,1], up_ramp_16Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.85),label="16 Hz, 10/30")
plt.semilogy(up_ramp_20Hz_1030[skip_time:,1], up_ramp_20Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.9),label="20 Hz, 10/30")
plt.semilogy(up_ramp_30Hz_1030[skip_time:,1], up_ramp_30Hz_1030[skip_time:,0],'.',ms=markerSize,c=cmap(0.95),label="30 Hz, 10/30")


plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="885">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_05Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_05Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/30),label="0.5 Hz, 11/5, 1")

plt.semilogy(up_ramp_4Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(4/30),label="4 Hz, 11/5, 1")
plt.semilogy(up_ramp_4Hz_02[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_02[skip_time:,0]),'.',ms=markerSize,c=cmap(4/30),label="4 Hz, 11/5, 2")

plt.semilogy(up_ramp_7Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_7Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(7/30),label="7 Hz, 10/30")

avg_up_ramp_8Hz = (up_ramp_8Hz_01[skip_time:,0]+up_ramp_8Hz_02[skip_time:,0])/2.0
plt.semilogy(up_ramp_8Hz_01[skip_time:,1], norm_by_avg_init(avg_up_ramp_8Hz),'.',ms=markerSize,c=cmap(8/30),label="8 Hz, 11/5, 1")

avg_up_ramp_12Hz = (up_ramp_12Hz_01[skip_time:,0]+up_ramp_12Hz_02[skip_time:,0]+up_ramp_12Hz_03[skip_time:,0])/3.0
plt.semilogy(up_ramp_12Hz_01[skip_time:,1], norm_by_avg_init(avg_up_ramp_12Hz),'.',ms=markerSize,c=cmap(12./30),label="12 Hz, 11/5, 1")

plt.semilogy(up_ramp_12Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(12/30),label="12 Hz, 10/30")
plt.semilogy(up_ramp_14Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_14Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(14/30),label="14 Hz, 10/30")
plt.semilogy(up_ramp_16Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_16Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(16/30),label="16 Hz, 10/30")
plt.semilogy(up_ramp_20Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_20Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(20/30),label="20 Hz, 10/30")
plt.semilogy(up_ramp_30Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_30Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(30/30),label="30 Hz, 10/30")


plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
main_dir = "Y:\\Dennis Terwilliger\\Data\\"
sub_dir = "2020-10-29\\"
filenm = "2020-10-29.csv"

up_ramp_1Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (1,2,3))
up_ramp_2Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (9,10,11))
up_ramp_3Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (17,18,19))
up_ramp_4Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (25,26,27))
up_ramp_5Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (33,34,35))
up_ramp_6Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (41,42,43))
up_ramp_7Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (49,50,51))
up_ramp_8Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (57,58,59))
up_ramp_9Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (65,66,67))
up_ramp_10Hz_1029 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (73,74,75))

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_1Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_1Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(1./30),label="1 Hz, 10/29")
plt.semilogy(up_ramp_2Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_2Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(2./30),label="2 Hz, 10/29")
plt.semilogy(up_ramp_3Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_3Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(3./30),label="3 Hz, 10/29")
plt.semilogy(up_ramp_4Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(4./30),label="4 Hz, 10/29")
plt.semilogy(up_ramp_5Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_5Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(5./30),label="5 Hz, 10/29")
plt.semilogy(up_ramp_6Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_6Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(6./30),label="6 Hz, 10/29")
plt.semilogy(up_ramp_7Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_7Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(7./30),label="7 Hz, 10/29")
plt.semilogy(up_ramp_8Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(8./30),label="8 Hz, 10/29")
plt.semilogy(up_ramp_9Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_9Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(9./30),label="9 Hz, 10/29")
plt.semilogy(up_ramp_10Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_10Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(10./30),label="10 Hz, 10/29")







plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="909">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10
alpha = 0.3
max_hz = 16

plt.semilogy(up_ramp_1Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_1Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(1./max_hz),label="1 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_2Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_2Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(2./max_hz),label="2 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_3Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_3Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(3./max_hz),label="3 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_4Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(4./max_hz),label="4 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_5Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_5Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(5./max_hz),label="5 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_6Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_6Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(6./max_hz),label="6 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_7Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_7Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(7./max_hz),label="7 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_8Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(8./max_hz),label="8 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_9Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_9Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(9./max_hz),label="9 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_10Hz_1029[skip_time:,1], norm_by_avg_init(up_ramp_10Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(10./max_hz),label="10 Hz, 10/29", alpha=alph)


plt.semilogy(up_ramp_05Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_05Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/max_hz),label="0.5 Hz, 11/5, 1", alpha=alph)

plt.semilogy(up_ramp_4Hz_01[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(4/max_hz),label="4 Hz, 11/5, 1", alpha=alph)
plt.semilogy(up_ramp_4Hz_02[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_02[skip_time:,0]),'.',ms=markerSize,c=cmap(4/max_hz),label="4 Hz, 11/5, 2", alpha=alph)

plt.semilogy(up_ramp_7Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_7Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(7/max_hz),label="7 Hz, 10/30", alpha=alph)

avg_up_ramp_8Hz = (up_ramp_8Hz_01[skip_time:,0]+up_ramp_8Hz_02[skip_time:,0])/2.0
plt.semilogy(up_ramp_8Hz_01[skip_time:,1], norm_by_avg_init(avg_up_ramp_8Hz),'.',ms=markerSize,c=cmap(8/max_hz),label="8 Hz, 11/5, 1", alpha=alph)

avg_up_ramp_12Hz = (up_ramp_12Hz_01[skip_time:,0]+up_ramp_12Hz_02[skip_time:,0]+up_ramp_12Hz_03[skip_time:,0])/3.0
plt.semilogy(up_ramp_12Hz_01[skip_time:,1], norm_by_avg_init(avg_up_ramp_12Hz),'.',ms=markerSize,c=cmap(12./max_hz),label="12 Hz, 11/5, 1", alpha=alph)

plt.semilogy(up_ramp_12Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(12/max_hz),label="12 Hz, 10/30", alpha=alph)
plt.semilogy(up_ramp_14Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_14Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(14/max_hz),label="14 Hz, 10/30", alpha=alph)
plt.semilogy(up_ramp_16Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_16Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(16/max_hz),label="16 Hz, 10/30", alpha=alph)
#plt.semilogy(up_ramp_20Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_20Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(20/30),label="20 Hz, 10/30", alpha=alph)
#plt.semilogy(up_ramp_30Hz_1030[skip_time:,1], norm_by_avg_init(up_ramp_30Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(30/30),label="30 Hz, 10/30", alpha=alph)





plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
#plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Text(0, 0.5, 'Viscosity (Pa s)')

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10
alph = 0.1

plt.semilogy(up_ramp_1Hz_1029[skip_time:,1], (up_ramp_1Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(1./30),label="1 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_2Hz_1029[skip_time:,1], (up_ramp_2Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(2./30),label="2 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_3Hz_1029[skip_time:,1], (up_ramp_3Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(3./30),label="3 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_4Hz_1029[skip_time:,1], (up_ramp_4Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(4./30),label="4 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_5Hz_1029[skip_time:,1], (up_ramp_5Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(5./30),label="5 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_6Hz_1029[skip_time:,1], (up_ramp_6Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(6./30),label="6 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_7Hz_1029[skip_time:,1], (up_ramp_7Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(7./30),label="7 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_8Hz_1029[skip_time:,1], (up_ramp_8Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(8./30),label="8 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_9Hz_1029[skip_time:,1], (up_ramp_9Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(9./30),label="9 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_10Hz_1029[skip_time:,1], (up_ramp_10Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(10./30),label="10 Hz, 10/29", alpha=alph)


plt.semilogy(up_ramp_05Hz_01[skip_time:,1], (up_ramp_05Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/30),label="0.5 Hz, 11/5, 1", alpha=alph)

plt.semilogy(up_ramp_4Hz_01[skip_time:,1], (up_ramp_4Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(4/30),label="4 Hz, 11/5, 1", alpha=alph)
plt.semilogy(up_ramp_4Hz_02[skip_time:,1], (up_ramp_4Hz_02[skip_time:,0]),'.',ms=markerSize,c=cmap(4/30),label="4 Hz, 11/5, 2", alpha=alph)

plt.semilogy(up_ramp_7Hz_1030[skip_time:,1], (up_ramp_7Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(7/30),label="7 Hz, 10/30", alpha=alph)

avg_up_ramp_8Hz = (up_ramp_8Hz_01[skip_time:,0]+up_ramp_8Hz_02[skip_time:,0])/2.0
plt.semilogy(up_ramp_8Hz_01[skip_time:,1], (avg_up_ramp_8Hz),'.',ms=markerSize,c=cmap(8/30),label="8 Hz, 11/5, 1", alpha=alph)

avg_up_ramp_12Hz = (up_ramp_12Hz_01[skip_time:,0]+up_ramp_12Hz_02[skip_time:,0]+up_ramp_12Hz_03[skip_time:,0])/3.0
plt.semilogy(up_ramp_12Hz_01[skip_time:,1], (avg_up_ramp_12Hz),'.',ms=markerSize,c=cmap(12./30),label="12 Hz, 11/5, 1", alpha=alph)

plt.semilogy(up_ramp_12Hz_1030[skip_time:,1], (up_ramp_12Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(12/30),label="12 Hz, 10/30", alpha=alph)
plt.semilogy(up_ramp_14Hz_1030[skip_time:,1], (up_ramp_14Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(14/30),label="14 Hz, 10/30", alpha=alph)
plt.semilogy(up_ramp_16Hz_1030[skip_time:,1], (up_ramp_16Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(16/30),label="16 Hz, 10/30", alpha=alph)
plt.semilogy(up_ramp_20Hz_1030[skip_time:,1], (up_ramp_20Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(20/30),label="20 Hz, 10/30", alpha=alph)
plt.semilogy(up_ramp_30Hz_1030[skip_time:,1], (up_ramp_30Hz_1030[skip_time:,0]),'.',ms=markerSize,c=cmap(30/30),label="30 Hz, 10/30", alpha=alph)





plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
#plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="994">
# Text(0, 0.5, 'Viscosity (Pa s)')

# %% [markdown]
# ### Data from 10/15

# %%
main_dir = "Y:\\Dennis Terwilliger\\Data\\"
sub_dir = "2020-10-15\\"
filenm = "2020-10-15.csv"

up_ramp_2Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (1,2,3))
up_ramp_3Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (5,6,7))
up_ramp_4Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (9,10,11))
up_ramp_5Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (13,14,15))
up_ramp_6Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (17,18,19))
up_ramp_7Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (21,22,23))
up_ramp_8Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (25,26,27))
up_ramp_9Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (29,30,31))
up_ramp_10Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (33,34,35))
up_ramp_12Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (37,38,39))
up_ramp_14Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (41,42,43))
up_ramp_16Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (45,46,47))
up_ramp_18Hz_1015 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (49,50,51))

# %%
time_to_temp = interpolate.interp1d(up_ramp_2Hz_1015[:,1],up_ramp_2Hz_1015[:,2],bounds_error=False)

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_2Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_2Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(2./30),label="2 Hz, 10/15")
plt.semilogy(up_ramp_3Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_3Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(3./30),label="3 Hz, 10/15")
plt.semilogy(up_ramp_4Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(4./30),label="4 Hz, 10/15")
plt.semilogy(up_ramp_5Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_5Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(5./30),label="5 Hz, 10/15")
plt.semilogy(up_ramp_6Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_6Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(6./30),label="6 Hz, 10/15")
plt.semilogy(up_ramp_7Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_7Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(7./30),label="7 Hz, 10/15")
plt.semilogy(up_ramp_8Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(8./30),label="8 Hz, 10/15")
plt.semilogy(up_ramp_9Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_9Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(9./30),label="9 Hz, 10/15")
plt.semilogy(up_ramp_10Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_10Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(10./30),label="10 Hz, 10/15")
plt.semilogy(up_ramp_12Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(12./30),label="12 Hz, 10/15")
plt.semilogy(up_ramp_14Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_14Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(14./30),label="14 Hz, 10/15")
plt.semilogy(up_ramp_16Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_16Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(16./30),label="16 Hz, 10/15")
plt.semilogy(up_ramp_18Hz_1015[skip_time:,1], norm_by_avg_init(up_ramp_18Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(18./30),label="18 Hz, 10/15")




plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 8.0
#fig, axs = plt.subplots(2, 1, sharex=True, figsize=(figsize, figsize/1.618))
fig = plt.figure(constrained_layout=True, figsize = (figsize, figsize/1.618))
spec = fig.add_gridspec(ncols=1, nrows=2, width_ratios=[1],
                          height_ratios=[0.25,1])
#ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 8


ax0 = fig.add_subplot(spec[0, 0])
ax1 = fig.add_subplot(spec[1, 0])

axs = [ax0, ax1]

axs[0].plot(up_ramp_2Hz_1015[skip_time:,1],up_ramp_2Hz_1015[skip_time:,2],'.',ms=markerSize, c = '0.4')
axs[0].set_ylabel("Temperature ($\degree$C)")

maxhz=18
axs[1].semilogy(up_ramp_2Hz_1015[skip_time:,1], (up_ramp_2Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(2./maxhz),label="2 Hz, 10/15")
axs[1].semilogy(up_ramp_3Hz_1015[skip_time:,1], (up_ramp_3Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(3./maxhz),label="3 Hz, 10/15")
axs[1].semilogy(up_ramp_4Hz_1015[skip_time:,1], (up_ramp_4Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(4./maxhz),label="4 Hz, 10/15")
axs[1].semilogy(up_ramp_5Hz_1015[skip_time:,1], (up_ramp_5Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(5./maxhz),label="5 Hz, 10/15")
axs[1].semilogy(up_ramp_6Hz_1015[skip_time:,1], (up_ramp_6Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(6./maxhz),label="6 Hz, 10/15")
axs[1].semilogy(up_ramp_7Hz_1015[skip_time:,1], (up_ramp_7Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(7./maxhz),label="7 Hz, 10/15")
axs[1].semilogy(up_ramp_8Hz_1015[skip_time:,1], (up_ramp_8Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(8./maxhz),label="8 Hz, 10/15")
axs[1].semilogy(up_ramp_9Hz_1015[skip_time:,1], (up_ramp_9Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(9./maxhz),label="9 Hz, 10/15")
axs[1].semilogy(up_ramp_10Hz_1015[skip_time:,1], (up_ramp_10Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(10./maxhz),label="10 Hz, 10/15")
axs[1].semilogy(up_ramp_12Hz_1015[skip_time:,1], (up_ramp_12Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(12./maxhz),label="12 Hz, 10/15")
axs[1].semilogy(up_ramp_14Hz_1015[skip_time:,1], (up_ramp_14Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(14./maxhz),label="14 Hz, 10/15")
axs[1].semilogy(up_ramp_16Hz_1015[skip_time:,1], (up_ramp_16Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(16./maxhz),label="16 Hz, 10/15")
axs[1].semilogy(up_ramp_18Hz_1015[skip_time:,1], (up_ramp_18Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(18./maxhz),label="18 Hz, 10/15")

plt.xlabel("Time (s)",fontsize=11)
plt.ylabel("Viscosity (Pa$\cdot$s)",fontsize=11)
#plt.legend(loc=0,fontsize=9)

axs[1].set_yticks([0.1])
axs[1].set_yticks([0.04,0.06,0.08,0.2],minor=True)
axs[1].set_yticklabels(["0.1"])
axs[1].set_yticklabels(["0.04","0.06","0.08","0.2"],minor=True)

fig.subplots_adjust(hspace=0)

fig.savefig("visc_vs_time_2020-10-15_Data_2Hzto18Hz.svg")
# Out:
# <img src="data:image/png;base64,..." width="800">
# <ipython-input-41-750ec4dd2c39>:45: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.
#   fig.subplots_adjust(hspace=0)

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 10.0
fig, ax = plt.subplots(figsize=(6,8.0/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10
stoptime=460

maxhz=18
plt.semilogy(time_to_temp(up_ramp_2Hz_1015[skip_time:stoptime,1]), (up_ramp_2Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(2./maxhz),label="2 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_3Hz_1015[skip_time:stoptime,1]), (up_ramp_3Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(3./maxhz),label="3 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_4Hz_1015[skip_time:stoptime,1]), (up_ramp_4Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(4./maxhz),label="4 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_5Hz_1015[skip_time:stoptime,1]), (up_ramp_5Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(5./maxhz),label="5 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_6Hz_1015[skip_time:stoptime,1]), (up_ramp_6Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(6./maxhz),label="6 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_7Hz_1015[skip_time:stoptime,1]), (up_ramp_7Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(7./maxhz),label="7 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_8Hz_1015[skip_time:stoptime,1]), (up_ramp_8Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(8./maxhz),label="8 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_9Hz_1015[skip_time:stoptime,1]), (up_ramp_9Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(9./maxhz),label="9 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_10Hz_1015[skip_time:stoptime,1]), (up_ramp_10Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(10./maxhz),label="10 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_12Hz_1015[skip_time:stoptime,1]), (up_ramp_12Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(12./maxhz),label="12 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_14Hz_1015[skip_time:stoptime,1]), (up_ramp_14Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(14./maxhz),label="14 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_16Hz_1015[skip_time:stoptime,1]), (up_ramp_16Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(16./maxhz),label="16 Hz, 10/15")
plt.semilogy(time_to_temp(up_ramp_18Hz_1015[skip_time:stoptime,1]), (up_ramp_18Hz_1015[skip_time:stoptime,0]),'.',ms=markerSize,c=cmap(18./maxhz),label="18 Hz, 10/15")


plt.xlabel("Temperature ($\degree$C)",fontsize=11)
plt.ylabel("Viscosity (Pa$\cdot$s)",fontsize=11)
plt.xlim(27,35.0)
ax.set_yticks([0.1])
ax.set_yticks([0.04,0.06,0.08,0.2],minor=True)
ax.set_yticklabels(["0.1"],fontsize=9)
ax.set_yticklabels(["0.04","0.06","0.08","0.2"],minor=True,fontsize=9)
plt.xticks(fontsize=9)
#plt.legend(loc=0,fontsize=9)

fig.savefig("visc_vs_temp_2020-10-15_Data_2Hzto18Hz.svg")
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Data from 11/6 (images were taken with the 4x objective)

# %%
main_dir = "Y:\\Dennis Terwilliger\\Data\\"
sub_dir = "2020-11-06\\"
filenm = "2020-11-06 Trios Data.csv"

up_ramp_05Hz_1106 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (1,2,3), max_rows=500)
up_ramp_4Hz_1106 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (5,6,7), max_rows=500)
up_ramp_8Hz_01_1106 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (9,10,11), max_rows=500)
up_ramp_12Hz_1106 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (13,14,15))
up_ramp_8Hz_02_1106 = np.loadtxt(main_dir+sub_dir+filenm, delimiter=',', skiprows = 6, usecols = (17,18,19))

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_05Hz_1106[skip_time:,1], (up_ramp_05Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/12),label="0.5 Hz, 11/6")
plt.semilogy(up_ramp_4Hz_1106[skip_time:,1], (up_ramp_4Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(4./12),label="4 Hz, 11/6")
plt.semilogy(up_ramp_8Hz_01_1106[skip_time:,1], (up_ramp_8Hz_01_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(8./12),label="8 Hz, 1, 11/6")
plt.semilogy(up_ramp_8Hz_02_1106[skip_time:,1], (up_ramp_8Hz_02_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(8./12),label="8 Hz, 2, 11/6")
plt.semilogy(up_ramp_12Hz_1106[skip_time:,1], (up_ramp_12Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(12./12),label="12 Hz, 11/6")


plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_05Hz_1106[skip_time:,1], norm_by_avg_init(up_ramp_05Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/12),label="0.5 Hz, 11/6")
plt.semilogy(up_ramp_4Hz_1106[skip_time:,1], norm_by_avg_init(up_ramp_4Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(4./12),label="4 Hz, 11/6")
plt.semilogy(up_ramp_8Hz_01_1106[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_01_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(8./12),label="8 Hz, 1, 11/6")
plt.semilogy(up_ramp_8Hz_02_1106[skip_time:,1], norm_by_avg_init(up_ramp_8Hz_02_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(8./12),label="8 Hz, 2, 11/6")
plt.semilogy(up_ramp_12Hz_1106[skip_time:,1], norm_by_avg_init(up_ramp_12Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(12./12),label="12 Hz, 11/6")


plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Relative Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

plt.semilogy(up_ramp_05Hz_1106[skip_time:,2], norm_by_avg_init(up_ramp_05Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/12),label="0.5 Hz, 11/6")
plt.semilogy(up_ramp_4Hz_1106[skip_time:,2], norm_by_avg_init(up_ramp_4Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(4./12),label="4 Hz, 11/6")
plt.semilogy(up_ramp_8Hz_01_1106[skip_time:,2], norm_by_avg_init(up_ramp_8Hz_01_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(8./12),label="8 Hz, 1, 11/6")
plt.semilogy(up_ramp_8Hz_02_1106[skip_time:,2], norm_by_avg_init(up_ramp_8Hz_02_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(8./12),label="8 Hz, 2, 11/6")
plt.semilogy(up_ramp_12Hz_1106[skip_time:,2], norm_by_avg_init(up_ramp_12Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(12./12),label="12 Hz, 11/6")


plt.xlabel("Temperature ($\degree$C)",fontsize=9)
plt.ylabel("Relative Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# #### All the 0.5 Hz to 2 Hz data

# %%
skip_time = 4
cmap = matplotlib.cm.get_cmap('RdYlBu')

figsize = 6.0
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
ax.tick_params(axis='both', which='major', labelsize=7)
markerSize = 10

max_hz = 2

alph=0.6

#f = norm_by_avg_init
def f(data):
    return data

plt.semilogy(up_ramp_05Hz_1106[skip_time:,1], f(up_ramp_05Hz_1106[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/max_hz),label="0.5 Hz, 11/6", alpha=alph)
plt.semilogy(up_ramp_05Hz_01[skip_time:,1], f(up_ramp_05Hz_01[skip_time:,0]),'.',ms=markerSize,c=cmap(0.5/max_hz),label="0.5 Hz, 11/5, 1", alpha=alph)

plt.semilogy(up_ramp_2Hz_1015[skip_time:,1], f(up_ramp_2Hz_1015[skip_time:,0]),'.',ms=markerSize,c=cmap(2./max_hz),label="2 Hz, 10/15", alpha=alph)

plt.semilogy(up_ramp_1Hz_1029[skip_time:,1], f(up_ramp_1Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(1./max_hz),label="1 Hz, 10/29", alpha=alph)
plt.semilogy(up_ramp_2Hz_1029[skip_time:,1], f(up_ramp_2Hz_1029[skip_time:,0]),'.',ms=markerSize,c=cmap(2./max_hz),label="2 Hz, 10/29", alpha=alph)


plt.xlabel("Time (s)",fontsize=9)
plt.ylabel("Relative Viscosity (Pa s)",fontsize=9)
plt.legend(loc=0,fontsize=9)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ## Correlating with the image autocorrelation analysis

# %%
import pickle
data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\02_Temp Ramp 12Hz Trial 1\\Temp Ramp_12Hz_(23-34Deg)20x\\Temp Ramp_12Hz_(23-34Deg)20x_4\\"
data_file = "Temp Ramp_12Hz_(23-34Deg)20x_4__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_12hz_4 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\02_Temp Ramp 12Hz Trial 1\\Temp Ramp_12Hz_(23-34Deg)20x\\Temp Ramp_12Hz_(23-34Deg)20x_5\\"
data_file = "Temp Ramp_12Hz_(23-34Deg)20x_5__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_12hz_5 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\02_Temp Ramp 12Hz Trial 1\\Temp Ramp_12Hz_(23-34Deg)20x\\Temp Ramp_12Hz_(23-34Deg)20x_6\\"
data_file = "Temp Ramp_12Hz_(23-34Deg)20x_6__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_12hz_6 = pickle.load(data_dump_file)
data_dump_file.close()


data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\02_Temp Ramp 12Hz Trial 1\\Temp Ramp_12Hz_(23-34Deg)20x\\Temp Ramp_12Hz_(23-34Deg)20x_7\\"
data_file = "Temp Ramp_12Hz_(23-34Deg)20x_7__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_12hz_7 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\02_Temp Ramp 12Hz Trial 1\\Temp Ramp_12Hz_(23-34Deg)20x\\Temp Ramp_12Hz_(23-34Deg)20x_8\\"
data_file = "Temp Ramp_12Hz_(23-34Deg)20x_8__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_12hz_8 = pickle.load(data_dump_file)
data_dump_file.close()

# %%
data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\01_Temp Ramp 4Hz Trial 1\\Temp Ramp_4Hz_(23-34Deg)20x\\Temp Ramp_4Hz_(23-34Deg)20x_4\\"
data_file = "Temp Ramp_4Hz_(23-34Deg)20x_4__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_4hz_4 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\01_Temp Ramp 4Hz Trial 1\\Temp Ramp_4Hz_(23-34Deg)20x\\Temp Ramp_4Hz_(23-34Deg)20x_5\\"
data_file = "Temp Ramp_4Hz_(23-34Deg)20x_5__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_4hz_5 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\01_Temp Ramp 4Hz Trial 1\\Temp Ramp_4Hz_(23-34Deg)20x\\Temp Ramp_4Hz_(23-34Deg)20x_6\\"
data_file = "Temp Ramp_4Hz_(23-34Deg)20x_6__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_4hz_6 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\01_Temp Ramp 4Hz Trial 1\\Temp Ramp_4Hz_(23-34Deg)20x\\Temp Ramp_4Hz_(23-34Deg)20x_7\\"
data_file = "Temp Ramp_4Hz_(23-34Deg)20x_7__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_4hz_7 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\01_Temp Ramp 4Hz Trial 1\\Temp Ramp_4Hz_(23-34Deg)20x\\Temp Ramp_4Hz_(23-34Deg)20x_8\\"
data_file = "Temp Ramp_4Hz_(23-34Deg)20x_8__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_4hz_8 = pickle.load(data_dump_file)
data_dump_file.close()

data_dir = "Y:\\Dennis Terwilliger\\Data\\2020-11-05\\01_Temp Ramp 4Hz Trial 1\\Temp Ramp_4Hz_(23-34Deg)20x\\Temp Ramp_4Hz_(23-34Deg)20x_9\\"
data_file = "Temp Ramp_4Hz_(23-34Deg)20x_9__pickleddata_filtsize500.p"
data_dump_file = open(data_dir+data_file,'rb')
sia_4hz_9 = pickle.load(data_dump_file)
data_dump_file.close()

# %%
sia_4hz_6['af_upto20']
# Out:
# array([ 1.75186662,  1.42909235,  1.07871221,  1.43259376,  1.26423809,
#         2.05080411,  1.88148213,  1.52744883,  1.24372826,  0.19222879,
#         0.48932406,  0.46782813,  0.31344627,  0.82002464,  1.05521803,
#         0.30625657,  0.63384857,  0.25187645,  0.33985532,  0.19325904,
#        -0.18145549,  0.0786252 ,  0.70563002,  0.57513788,  0.4314969 ,
#         0.30628071, -0.18536417, -0.57726506, -0.06499529,  0.1409171 ,
#        -0.04998288,  0.76111504,  1.25812545,  1.90059565,  2.0346088 ,
#         1.69835121,  2.15186731,  1.90977681,  1.93994312,  1.50259823,
#         1.6417715 ,  1.88378354,  2.26696108,  2.4718964 ,  2.31872609,
#         2.47758854,  2.79587859,  1.99362155,  2.04292242,  2.51541782,
#         1.52235366,  1.78082545,  1.58559928,  1.25974055,  0.29488041,
#         0.81024601,  1.58257765,  1.16826145,  0.99260439,  0.98510978,
#         1.16962074,  0.55115414, -0.19214494,  0.64257811,  0.088393  ,
# ...

# %%
sia_12hz['corr_images'].shape
# Out:
# (80, 492, 596)

# %%
val = 0.7

xvalues = np.arange(x_mid+1)*0.501
ycorr_sia_12hz_4 = np.zeros((sia_12hz_4['corr_images'].shape[0], 247))
ycorr12_4_50 = np.zeros((ycorr_sia_12hz_4.shape[0]))
nx,ny = sia_12hz_4['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_12hz_4)):
    slice_sia = np.flip(sia_12hz_4['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_12hz_4[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr12_4_50[i] = xvalues[w]
times_to_analyze12_4 = 312 + np.arange(0,2000,25)/88.

xvalues = np.arange(x_mid+1)*0.501
ycorr_sia_12hz_5 = np.zeros((sia_12hz_5['corr_images'].shape[0], 247))
ycorr12_5_50 = np.zeros((ycorr_sia_12hz_5.shape[0]))
nx,ny = sia_12hz_5['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_12hz_5)):
    slice_sia = np.flip(sia_12hz_5['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_12hz_5[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr12_5_50[i] = xvalues[w]
times_to_analyze12_5 = 340 + np.arange(0,2000,25)/88.

xvalues = np.arange(x_mid+1)*0.501
ycorr_sia_12hz_6 = np.zeros((sia_12hz_6['corr_images'].shape[0], 247))
ycorr12_6_50 = np.zeros((ycorr_sia_12hz_6.shape[0]))
nx,ny = sia_12hz_6['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_12hz_6)):
    slice_sia = np.flip(sia_12hz_6['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_12hz_6[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr12_6_50[i] = xvalues[w]
times_to_analyze12_6 = 364 + np.arange(0,2000,25)/88.

xvalues = np.arange(x_mid+1)*0.501
ycorr_sia_12hz_7 = np.zeros((sia_12hz_7['corr_images'].shape[0], 247))
ycorr12_7_50 = np.zeros((ycorr_sia_12hz_7.shape[0]))
nx,ny = sia_12hz_7['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_12hz_7)):
    slice_sia = np.flip(sia_12hz_7['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_12hz_7[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr12_7_50[i] = xvalues[w]
times_to_analyze12_7 = 390 + np.arange(0,2000,25)/88.

xvalues = np.arange(x_mid+1)*0.501
ycorr_sia_12hz_8 = np.zeros((sia_12hz_8['corr_images'].shape[0], 247))
ycorr12_8_50 = np.zeros((ycorr_sia_12hz_8.shape[0]))
nx,ny = sia_12hz_8['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_12hz_8)):
    slice_sia = np.flip(sia_12hz_8['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_12hz_8[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr12_8_50[i] = xvalues[w]
times_to_analyze12_8 = 414 + np.arange(0,2000,25)/88.

# %%
val = 0.7

xvalues = np.arange(x_mid+1)*0.501
ycorr_sia_4hz_4 = np.zeros((sia_4hz_4['corr_images'].shape[0], 247))
ycorr4_4_50 = np.zeros((ycorr_sia_4hz_4.shape[0]))
nx,ny = sia_4hz_4['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_4hz_4)):
    slice_sia = np.flip(sia_4hz_4['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_4hz_4[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr4_4_50[i] = xvalues[w]
times_to_analyze4_4 = 313 + np.arange(0,2000,25)/88.

ycorr_sia_4hz_5 = np.zeros((sia_4hz_5['corr_images'].shape[0], 247))
ycorr4_5_50 = np.zeros((ycorr_sia_4hz_5.shape[0]))
nx,ny = sia_4hz_5['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_4hz_5)):
    slice_sia = np.flip(sia_4hz_5['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_4hz_5[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr4_5_50[i] = xvalues[w]
times_to_analyze4_5 = 340 + np.arange(0,2000,25)/88.

ycorr_sia_4hz_6 = np.zeros((sia_4hz_6['corr_images'].shape[0], 247))
ycorr4_6_50 = np.zeros((ycorr_sia_4hz_6.shape[0]))
nx,ny = sia_4hz_6['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_4hz_6)):
    slice_sia = np.flip(sia_4hz_6['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_4hz_6[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr4_6_50[i] = xvalues[w]
times_to_analyze4_6 = 364 + np.arange(0,2000,25)/88.

ycorr_sia_4hz_7 = np.zeros((sia_4hz_7['corr_images'].shape[0], 247))
ycorr4_7_50 = np.zeros((ycorr_sia_4hz_7.shape[0]))
nx,ny = sia_4hz_7['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_4hz_7)):
    slice_sia = np.flip(sia_4hz_7['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_4hz_7[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr4_7_50[i] = xvalues[w]
times_to_analyze4_7 = 390 + np.arange(0,2000,25)/88.

ycorr_sia_4hz_8 = np.zeros((sia_4hz_8['corr_images'].shape[0], 247))
ycorr4_8_50 = np.zeros((ycorr_sia_4hz_8.shape[0]))
nx,ny = sia_4hz_8['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_4hz_8)):
    slice_sia = np.flip(sia_4hz_8['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_4hz_8[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr4_8_50[i] = xvalues[w]
times_to_analyze4_8 = 413 + np.arange(0,2000,25)/88.

ycorr_sia_4hz_9 = np.zeros((sia_4hz_9['corr_images'].shape[0], 247))
ycorr4_9_50 = np.zeros((ycorr_sia_4hz_9.shape[0]))
nx,ny = sia_4hz_9['corr_images'][0].shape
x_mid = int(nx/2); y_mid = int(ny/2)
for i in range(len(ycorr_sia_4hz_9)):
    slice_sia = np.flip(sia_4hz_9['corr_images'][i,0:x_mid+1, y_mid])
    ycorr_sia_4hz_9[i] = slice_sia
    w = np.argmin(np.abs(slice_sia-val))
    ycorr4_9_50[i] = xvalues[w]
times_to_analyze4_9 = 440 + np.arange(0,2000,25)/88.

# %%
sia_4hz_9['af'][:,1:].sum(axis=1).shape
# Out:
# (80,)

# %%
figsize = 10.0
gf_size = 4
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
plt.plot(times_to_analyze12_4,ycorr12_4_50,'ro')
plt.plot(times_to_analyze12_4,gf1d(ycorr12_4_50,gf_size),'bo')
plt.plot(times_to_analyze12_5,ycorr12_5_50,'ro')
plt.plot(times_to_analyze12_5,gf1d(ycorr12_5_50,gf_size),'bo')
plt.plot(times_to_analyze12_6,ycorr12_6_50,'ro')
plt.plot(times_to_analyze12_6,gf1d(ycorr12_6_50,gf_size),'bo')
plt.plot(times_to_analyze12_7,ycorr12_7_50,'ro')
plt.plot(times_to_analyze12_7,gf1d(ycorr12_7_50,gf_size),'bo')
plt.plot(times_to_analyze12_8,ycorr12_8_50,'ro')
plt.plot(times_to_analyze12_8,gf1d(ycorr12_8_50,gf_size),'bo')

plt.plot(times_to_analyze4_4,ycorr4_4_50,'go')
plt.plot(times_to_analyze4_4,gf1d(ycorr4_4_50,gf_size),'mo')
plt.plot(times_to_analyze4_5,ycorr4_5_50,'go')
plt.plot(times_to_analyze4_5,gf1d(ycorr4_5_50,gf_size),'mo')
plt.plot(times_to_analyze4_6,ycorr4_6_50,'go')
plt.plot(times_to_analyze4_6,gf1d(ycorr4_6_50,gf_size),'mo')
plt.plot(times_to_analyze4_7,ycorr4_7_50,'go')
plt.plot(times_to_analyze4_7,gf1d(ycorr4_7_50,gf_size),'mo')
plt.plot(times_to_analyze4_8,ycorr4_8_50,'go')
plt.plot(times_to_analyze4_8,gf1d(ycorr4_8_50,gf_size),'mo')
plt.plot(times_to_analyze4_9,ycorr4_9_50,'go')
plt.plot(times_to_analyze4_9,gf1d(ycorr4_9_50,gf_size),'mo')
plt.title("11/5 - 4 Hz and 12 Hz")

figsize = 10.0
gf_size = 10
fig, ax = plt.subplots(figsize=(figsize,figsize/1.618))
plt.plot(times_to_analyze12_4,sia_12hz_4['af_upto20'],'ro')
plt.plot(times_to_analyze12_5,sia_12hz_5['af_upto20'],'ro')
plt.plot(times_to_analyze12_6,sia_12hz_6['af_upto20'],'ro')
plt.plot(times_to_analyze12_7,sia_12hz_7['af_upto20'],'ro')
plt.plot(times_to_analyze12_8,sia_12hz_8['af_upto20'],'ro')
plt.plot(times_to_analyze4_4,sia_4hz_4['af_upto20'],'go')
plt.plot(times_to_analyze4_5,sia_4hz_5['af_upto20'],'go')
plt.plot(times_to_analyze4_6,sia_4hz_6['af_upto20'],'go')
plt.plot(times_to_analyze4_7,sia_4hz_7['af_upto20'],'go')
plt.plot(times_to_analyze4_8,sia_4hz_8['af_upto20'],'go')
plt.plot(times_to_analyze4_9,sia_4hz_9['af_upto20'],'go')
plt.title("11/5 - 4 Hz and 12 Hz")
# Out:
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, '11/5 - 4 Hz and 12 Hz')

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel("time (s)")
ax1.semilogy(up_ramp_12Hz_01[skip_time:500,1], norm_by_avg_init(up_ramp_12Hz_01[skip_time:500,0]),'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 1")
ax1.semilogy(up_ramp_4Hz_01[skip_time:500,1], norm_by_avg_init(up_ramp_4Hz_01[skip_time:500,0]),'.',ms=markerSize,c=cmap(0.2),label="12 Hz, 11/5, 1")

ax2 = ax1.twinx()
gf_size=1
ax2.plot(times_to_analyze12_4,gf1d(ycorr12_4_50,gf_size),'s',c=cmap(0.75))
ax2.plot(times_to_analyze12_5,gf1d(ycorr12_5_50,gf_size),'s',c=cmap(0.75))
ax2.plot(times_to_analyze12_6,gf1d(ycorr12_6_50,gf_size),'s',c=cmap(0.75))
ax2.plot(times_to_analyze12_7,gf1d(ycorr12_7_50,gf_size),'s',c=cmap(0.75))
ax2.plot(times_to_analyze12_8,gf1d(ycorr12_8_50,gf_size),'s',c=cmap(0.75))
ax2.plot(times_to_analyze4_4,gf1d(ycorr4_4_50,gf_size),'s',c=cmap(0.25))
ax2.plot(times_to_analyze4_5,gf1d(ycorr4_5_50,gf_size),'s',c=cmap(0.25))
ax2.plot(times_to_analyze4_6,gf1d(ycorr4_6_50,gf_size),'s',c=cmap(0.25))
ax2.plot(times_to_analyze4_7,gf1d(ycorr4_7_50,gf_size),'s',c=cmap(0.25))
ax2.plot(times_to_analyze4_8,gf1d(ycorr4_8_50,gf_size),'s',c=cmap(0.25))
ax2.plot(times_to_analyze4_9,gf1d(ycorr4_9_50,gf_size),'s',c=cmap(0.25))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel("time (s)")
ax1.semilogy(up_ramp_12Hz_01[skip_time:500,1], norm_by_avg_init(up_ramp_12Hz_01[skip_time:500,0]),'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 1")
ax1.semilogy(up_ramp_4Hz_01[skip_time:500,1], norm_by_avg_init(up_ramp_4Hz_01[skip_time:500,0]),'.',ms=markerSize,c=cmap(0.2),label="12 Hz, 11/5, 1")

ax2 = ax1.twinx()
gf_size=1
markSize=2
ax2.plot(times_to_analyze12_4,gf1d(sia_12hz_4['af_upto20'],gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_5,gf1d(sia_12hz_5['af_upto20'],gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_6,gf1d(sia_12hz_6['af_upto20'],gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_7,gf1d(sia_12hz_7['af_upto20'],gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_8,gf1d(sia_12hz_8['af_upto20'],gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze4_4,gf1d(sia_4hz_4['af_upto20'],gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_5,gf1d(sia_4hz_5['af_upto20'],gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_6,gf1d(sia_4hz_6['af_upto20'],gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_7,gf1d(sia_4hz_7['af_upto20'],gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_8,gf1d(sia_4hz_8['af_upto20'],gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_9,gf1d(sia_4hz_9['af_upto20'],gf_size),'s',c=cmap(0.25),ms=markSize)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
len(sia_12hz_4['af_upto20'])
# Out:
# 80

# %%
fig, ax1 = plt.subplots()
ax1.set_xlabel("time (s)")
ax1.semilogy(up_ramp_12Hz_01[skip_time:500,1], norm_by_avg_init(up_ramp_12Hz_01[skip_time:500,0]),'.',ms=markerSize,c=cmap(0.7),label="12 Hz, 11/5, 1")
ax1.semilogy(up_ramp_4Hz_01[skip_time:500,1], norm_by_avg_init(up_ramp_4Hz_01[skip_time:500,0]),'.',ms=markerSize,c=cmap(0.2),label="12 Hz, 11/5, 1")

ax2 = ax1.twinx()
gf_size=6
markSize=2
start = 40
end = -1
ax2.plot(times_to_analyze12_4,gf1d(sia_12hz_4['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_5,gf1d(sia_12hz_5['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_6,gf1d(sia_12hz_6['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_7,gf1d(sia_12hz_7['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze12_8,gf1d(sia_12hz_8['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.75),ms=markSize)
ax2.plot(times_to_analyze4_4,gf1d(sia_4hz_4['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_5,gf1d(sia_4hz_5['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_6,gf1d(sia_4hz_6['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_7,gf1d(sia_4hz_7['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_8,gf1d(sia_4hz_8['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.25),ms=markSize)
ax2.plot(times_to_analyze4_9,gf1d(sia_4hz_9['af'][:,start:end].sum(axis=1),gf_size),'s',c=cmap(0.25),ms=markSize)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sia_12hz_4['af'][:,1:].shape
# Out:
# (80, 199)
